# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot
import matplotlib.pyplot as plt
from statsmodels. tsa.stattools import adfuller
from sklearn.model_selection import train_test_split
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
df = pd.read_csv('AirPassengers.csv')
df
# Out:
#        Month  #Passengers
# 0    1949-01          112
# 1    1949-02          118
# 2    1949-03          132
# 3    1949-04          129
# 4    1949-05          121
# ..       ...          ...
# 139  1960-08          606
# 140  1960-09          508
# 141  1960-10          461
# 142  1960-11          390
# 143  1960-12          432
#
# [144 rows x 2 columns]

# %%
x = range(1,13)
y1 = df['#Passengers'].iloc[:12]
y2 = df['#Passengers'].iloc[12:24]
y3 = df['#Passengers'].iloc[24:36]
y4 = df['#Passengers'].iloc[36:48]
y5 = df['#Passengers'].iloc[48:60]
y6 = df['#Passengers'].iloc[60:72]
y7 = df['#Passengers'].iloc[72:84]
y8 = df['#Passengers'].iloc[84:96]
y9 = df['#Passengers'].iloc[96:108]
y10 = df['#Passengers'].iloc[108:120]
y11 = df['#Passengers'].iloc[120:132]
y12 = df['#Passengers'].iloc[132:]

df.iloc[24:36]
plt.plot(x,y1, label = '1949')
plt.plot(x,y2, label = '1950')
plt.plot(x,y3, label = '1951')
plt.plot(x,y4, label = '1952')
plt.plot(x,y5, label = '1953')
plt.plot(x,y6, label = '1954')
plt.plot(x,y7, label = '1955')
plt.plot(x,y8, label = '1956')
plt.plot(x,y9, label = '1957')
plt.plot(x,y10, label = '1958')
plt.plot(x,y11, label = '1959')
plt.plot(x,y12, label = '1960')
plt.legend()
plt.title('Изменения по сезонам')
plt.show()

# %%
x = df.plot(figsize = (12,6), legend = None)
x.set(title = 'с 1949 по 1960 год', xlabel = 'Месяца', ylabel = 'Кол-во пассажиров')
# Out:
# [Text(0.5, 1.0, 'с 1949 по 1960 год'),
#  Text(0.5, 0, 'Месяца'),
#  Text(0, 0.5, 'Кол-во пассажиров')]

# %%
df['Month'] = pd.to_datetime(df['Month'], infer_datetime_format=True)

# %%
df.set_index('Month', inplace = True)
df.head()
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121

# %%
adfuller(df['#Passengers'])
# Out:
# (0.8153688792060498,
#  0.991880243437641,
#  13,
#  130,
#  {'1%': -3.4816817173418295,
#   '5%': -2.8840418343195267,
#   '10%': -2.578770059171598},
#  996.692930839019)

# %%
train = df[:'1959-12']
test = df['1960-01':]

# %%
# !pip install pmdarima
from pmdarima.arima import auto_arima
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
model = auto_arima(df, seasonal=True, m=12, trace=True)
model.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,1,1)[12]             : AIC=1020.048, Time=3.21 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=1031.508, Time=0.04 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=1020.393, Time=0.16 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=1021.003, Time=0.27 sec
#  ARIMA(2,1,2)(0,1,1)[12]             : AIC=1019.935, Time=0.97 sec
#  ARIMA(2,1,2)(0,1,0)[12]             : AIC=1019.290, Time=0.38 sec
#  ARIMA(2,1,2)(1,1,0)[12]             : AIC=1019.546, Time=2.37 sec
#  ARIMA(1,1,2)(0,1,0)[12]             : AIC=1024.160, Time=0.35 sec
#  ARIMA(2,1,1)(0,1,0)[12]             : AIC=1017.847, Time=0.96 sec
#  ARIMA(2,1,1)(1,1,0)[12]             : AIC=1017.914, Time=1.89 sec
#  ARIMA(2,1,1)(0,1,1)[12]             : AIC=1018.359, Time=2.09 sec
#  ARIMA(2,1,1)(1,1,1)[12]             : AIC=1018.248, Time=4.99 sec
#  ARIMA(1,1,1)(0,1,0)[12]             : AIC=1022.393, Time=0.39 sec
# ...

# %%
model = ARIMA(train, order =(2,1,1), seasonal_order=(0,1,0, 12)).fit()
pred = model.forecast(steps=12)
# Out:
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# ...

# %%
print(mae(test, y_pred))
# Out:
# 19.63263055148704

# %%
mse = mean_squared_error(test, y_pred)
mse
# Out:
# 618.7212132605686

# %%
mape = mean_absolute_percentage_error(test, y_pred) 
mape
# Out:
# 0.044317549876554875

# %%
df['new_pas'] = df['#Passengers']
df
# Out:
#             #Passengers  new_pas
# Month
# 1949-01-01          112      112
# 1949-02-01          118      118
# 1949-03-01          132      132
# 1949-04-01          129      129
# 1949-05-01          121      121
# ...                 ...      ...
# 1960-08-01          606      606
# 1960-09-01          508      508
# 1960-10-01          461      461
# 1960-11-01          390      390
# 1960-12-01          432      432
#
# [144 rows x 2 columns]

# %%
df['new_pas'].iloc[132:] = y_pred

# %%
plt.figure(figsize =(12,10))
plt.plot(df['#Passengers'], color='green')  
plt.plot(df['new_pas'], color = 'red')
plt.xlabel("Date") 
plt.ylabel("Passengers")
# Out:
# Text(0, 0.5, 'Passengers')

# %%
model2 = ExponentialSmoothing(train, trend='add', seasonal = 'mul',seasonal_periods = 12)
fitted_model = model2.fit()
y_pred2 = fitted_model.forecast(steps=12)
# Out:
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
print(mae(test,y_pred2))
# Out:
# 10.299694207748567

# %%
mse2 = mean_squared_error(test, y_pred2)
mse2
# Out:
# 249.87287062171777

# %%
mape2 = mean_absolute_percentage_error(test, y_pred2) 
mape2
# Out:
# 0.022068259147480396

# %%
plt.figure(figsize =(12,10))
plt.plot(df['#Passengers'], color='green')  
plt.plot(y_pred2, color = 'red')
plt.xlabel("Date") 
plt.ylabel("Passengers")
# Out:
# Text(0, 0.5, 'Passengers')

# %%
plt.figure(figsize =(12,10))
plt.plot(df['#Passengers'], color='green',label = 'Passengers true')
plt.plot(y_pred, color = 'red',label = 'ARIMA prediction')
plt.plot(y_pred2, color = 'blue',label = 'ExponentialSmoothing predictions')
plt.xlabel("Date") 
plt.ylabel("Passengers")
plt.legend()
